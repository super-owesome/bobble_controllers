# %% [markdown]
# <center>
#   <font size="+3">BobbleBot Controller Analysis Report<br><br></font>
#   <font size="+2">Tuning Drive Control<br><br></font>
#   <i>Mike Moore<br>
#   <i>11/11/18<br>
#   <img src="imgs/BobbleCAD.png" alt="BobbleBot CAD" style="height: 350px; width: 250px;"/>
# </center>

# %% [markdown]
# # Introduction
# This document outlines an analysis of BobbleBot controller performance as different gains are selected. At first, the BobbleBot simulator is used to capture the data and characterize the controller performance. BLAH BLAH TODO
#
# New PIC NEEDED
# <center>
#     <br>
#   <img src="imgs/BobbleBotSimCg.png" alt="BobbleBot CG" style="height: 350px; width: 250px;"/>
# </center>

# %% [markdown]
# ## Loading BobbleBot Simulation Data

# %% [markdown]
# The BobbleBot simulator runs in Gazebo. Using the gazebo-ros packages, one can log data as the simulator runs and store it in a ros bag format. The simulation data can then be analyzed with Python using [Pandas](https://pandas.pydata.org/). This article discusses how to [load ROS bag files into Pandas](https://nimbus.unl.edu/2014/11/using-rosbag_pandas-to-analyze-rosbag-files/).

# %%
# Load anaylsis environment file. This file defines data directories
# and imports all needed Python packages for this notebook.
exec(open("env.py").read())

# %% [markdown]
# ### Load Plot Config

# %%
# Set paths to relevant data directories and config files
drive_tests_plot_config = os.path.abspath(os.path.join(os.getcwd(),'plots.yaml'))
# Load configs and data
pc = parse_config_file(drive_tests_plot_config)
# Out:
# Loading configs from file : /home/mike/Work/SOE/BobbleBot/src/analysis_tools/notebooks/DriveControlAnalysis/plots.yaml

# %% [markdown]
# ## Pre-Processing
# This section applies any and all pre-processing steps needed on the data set. Examples include trimming the data, removing bias, filtering, and applying transforms.

# %%
max_time = 8.0
#df['response_kp_1.1_kd_0.075'] = df['response_kp_1.1_kd_0.075'][df['response_kp_1.1_kd_0.075'].index < max_time]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-2c0c1c17ffda> in <module>()
#       1 max_time = 8.0
# ----> 2 df['response_kp_1.1_kd_0.075'] = df['response_kp_1.1_kd_0.075'][df['response_kp_1.1_kd_0.075'].index < max_time]
#
# KeyError: 'response_kp_1.1_kd_0.075'

# %%
df.keys()
# Out:
# ['cmds_turning',
#  'response_sim_hw_final',
#  'cmds_drive_square',
#  'response_fwd_bwd',
#  'response_hw_final',
#  'cmd_sim_final',
#  'cmds_hw_testing',
#  'response_drive_square',
#  'response_hw_turning',
#  'cmds_fwd_bwd',
#  'timing_fwd_bwd',
#  'response_sim_fwd_bwd',
#  'response_final',
#  'cmds_hw_final',
#  'response_hw_testing']

# %% [markdown]
# ## Compute Auxiliary Data
# BobbleBot does not track its x,y world position internally because it is not needed for the controller. For this analysis, we want to look at some commanded trajectories in world coordinates. To do this, we use a kinematic model for a differential drive robot in order to compute translational and rotational state.
#
# ### Differential Drive Model
#
# <center>
#     <br>
#   <img src="imgs/diff-model.png" alt="Differential Drive Model" style="height: 400px; width: 375px;"/>
# </center>
#
# The Python code below uses the differential drive model to compute x, y position and velocity in world co-ordinates.

# %%
import math

def apply_filters(df):
    turn_rate = df['bobble_bobble_balance_controller_bb_controller_status__TurnRate']
    filtered_sig = butter_lowpass_filter(turn_rate, 200.0, 5.0, order=3)
    df['bobble_bobble_balance_controller_bb_controller_status__TurnRate'] = filtered_sig

def compute_auxiliary_terms(df, fwd_vel_scale=1.0, turn_rate_scale=1.0):
    #left_motor_vel = df['bobble_bobble_balance_controller_bb_controller_status__LeftMotorVelocity']
    #right_motor_vel = df['bobble_bobble_balance_controller_bb_controller_status__RightMotorVelocity']
    #turn_rate = (wheel_radius/wheel_base_len)*(right_motor_vel - left_motor_vel)
    #heading = scipy.integrate.cumtrapz(y=turn_rate.values, x=turn_rate.index)
    #heading = np.append(heading, heading[-1])
    turn_rate = turn_rate_scale*df['bobble_bobble_balance_controller_bb_controller_status__TurnRate']
    heading = scipy.integrate.cumtrapz(y=turn_rate.values, x=turn_rate.index)
    heading = np.append(heading, heading[-1])
    fwd_vel = fwd_vel_scale*df['bobble_bobble_balance_controller_bb_controller_status__ForwardVelocity']
    
    x_vel = fwd_vel * np.cos(heading*np.pi/180.0)
    y_vel = fwd_vel * np.sin(heading*np.pi/180.0)
    
    x_pos = scipy.integrate.cumtrapz(y=x_vel.values, x=x_vel.index)
    x_pos = np.append(x_pos, x_pos[-1])
    y_pos = scipy.integrate.cumtrapz(y=y_vel.values, x=y_vel.index)
    y_pos = np.append(y_pos, y_pos[-1])
    
    desired_fwd_vel = fwd_vel_scale*df['bobble_bobble_balance_controller_bb_controller_status__DesiredVelocity']
    desired_turn_rate = turn_rate_scale*df['bobble_bobble_balance_controller_bb_controller_status__DesiredTurnRate']
    desired_heading = scipy.integrate.cumtrapz(y=desired_turn_rate.values, x=desired_turn_rate.index)
    desired_heading = np.append(desired_heading, desired_heading[-1])
    desired_x_vel = desired_fwd_vel * np.cos(desired_heading*np.pi/180.0)
    desired_y_vel = desired_fwd_vel * np.sin(desired_heading*np.pi/180.0)
    desired_x_pos = scipy.integrate.cumtrapz(y=desired_x_vel.values, x=desired_x_vel.index)
    desired_x_pos = np.append(desired_x_pos, desired_x_pos[-1])
    desired_y_pos = scipy.integrate.cumtrapz(y=desired_y_vel.values, x=desired_y_vel.index)
    desired_y_pos = np.append(desired_y_pos, desired_y_pos[-1])

    df['bobble_bobble_balance_controller_bb_controller_status__Heading'] = heading
    df['DerivedHeading'] = heading
    df['DesiredHeading'] = desired_heading
    df['DesiredXPos'] = desired_x_pos
    df['DesiredYPos'] = desired_y_pos
    df['DerivedXPos'] = x_pos
    df['DerivedYPos'] = y_pos

compute_auxiliary_terms(df['response_fwd_bwd'])
compute_auxiliary_terms(df['response_drive_square'])
compute_auxiliary_terms(df['response_final'])
compute_auxiliary_terms(df['response_hw_final'])
compute_auxiliary_terms(df['response_sim_hw_final'])

apply_filters(df['response_hw_testing'])
compute_auxiliary_terms(df['response_hw_testing'], fwd_vel_scale=0.405, turn_rate_scale=1.125)
apply_filters(df['response_hw_turning'])
compute_auxiliary_terms(df['response_hw_turning'])

# %% [markdown]
# ### Print sim data in tabular form
# All the sim data was loaded when the analysis env file was sourced. We can get the data for a run in tabular form like so.

# %%
n_rows = 5
df['response_drive_square'].head(n_rows)
# Out:
#           bobble_bobble_balance_controller_bb_controller_status__ControlMode  \
# time
# 0.000000                                                2.0
# 0.000057                                                2.0
# 0.007327                                                2.0
# 0.011164                                                2.0
# 0.016747                                                2.0
#
#           bobble_bobble_balance_controller_bb_controller_status__DesiredTilt  \
# time
# 0.000000                                      -2.160068e-11
# 0.000057                                      -1.151301e-01
# 0.007327                                      -1.527241e-01
# 0.011164                                      -1.371435e-01
# 0.016747                                      -1.046776e-01
#
#           bobble_bobble_balance_controller_bb_controller_status__DesiredTurnRate  \
# time
# 0.000000                                                0.0
# 0.000057                                                0.0
# 0.007327                                                0.0
# 0.011164                                                0.0
# 0.016747                                                0.0
#
#           bobble_bobble_balance_controller_bb_controller_status__DesiredVelocity  \
# time
# 0.000000                                                0.0
# 0.000057                                                0.0
# 0.007327                                                0.0
# 0.011164                                                0.0
# 0.016747                                                0.0
#
#           bobble_bobble_balance_controller_bb_controller_status__ForwardVelocity  \
# time
# 0.000000                                       8.370811e-13
# 0.000057                                       1.826727e-02
# 0.007327                                       1.601190e-02
# 0.011164                                       1.085557e-02
# 0.016747                                       6.816792e-03
#
#           bobble_bobble_balance_controller_bb_controller_status__Heading  \
# time
# 0.000000                                          -0.000273
# 0.000057                                          -0.014465
# 0.007327                                          -0.005069
# 0.011164                                           0.019037
# 0.016747                                           0.032641
#
#           bobble_bobble_balance_controller_bb_controller_status__HeadingEffort  \
# time
# 0.000000                                          -0.002694
# 0.000057                                          -0.004295
# 0.007327                                          -0.001754
# 0.011164                                           0.001936
# 0.016747                                           0.003807
#
#           bobble_bobble_balance_controller_bb_controller_status__LeftMotorEffortCmd  \
# time
# 0.000000                                           0.031756
# 0.000057                                           0.039959
# 0.007327                                           0.039378
# 0.011164                                           0.031136
# 0.016747                                           0.022687
#
#           bobble_bobble_balance_controller_bb_controller_status__LeftMotorPosition  \
# time
# 0.000000                                         145.709579
# 0.000057                                         145.665634
# 0.007327                                         145.643677
# 0.011164                                         145.621689
# 0.016747                                         145.709579
#
#           bobble_bobble_balance_controller_bb_controller_status__LeftMotorVelocity  \
# time
# 0.000000                                       1.384645e-09
# 0.000057                                       5.582066e+01
# 0.007327                                       3.497360e+01
# 0.011164                                       2.093998e+01
# 0.016747                                       1.253754e+01
#
#               ...       \
# time          ...
# 0.000000      ...
# 0.000057      ...
# 0.007327      ...
# 0.011164      ...
# 0.016747      ...
#
#           bobble_bobble_balance_controller_bb_controller_status__TiltEffort  \
# time
# 0.000000                                           0.034449
# 0.000057                                           0.044254
# 0.007327                                           0.041133
# 0.011164                                           0.029201
# 0.016747                                           0.018880
#
#           bobble_bobble_balance_controller_bb_controller_status__TiltRate  \
# time
# 0.000000                                          -6.707428
# 0.000057                                         -10.488384
# 0.007327                                          -7.320177
# 0.011164                                           2.493434
# 0.016747                                           8.738424
#
#           bobble_bobble_balance_controller_bb_controller_status__TurnRate  \
# time
# 0.000000                                          -5.025765
# 0.000057                                          -4.504931
# 0.007327                                           0.600862
# 0.011164                                           4.297477
# 0.016747                                           4.337548
#
#               time  DerivedHeading  DesiredHeading  DesiredXPos  DesiredYPos  \
# time
# 0.000000  0.000000       -0.000273             0.0          0.0          0.0
# 0.000057  0.000057       -0.014465             0.0          0.0          0.0
# 0.007327  0.007327       -0.005069             0.0          0.0          0.0
# 0.011164  0.011164        0.019037             0.0          0.0          0.0
# 0.016747  0.016747        0.032641             0.0          0.0          0.0
#
#            DerivedXPos   DerivedYPos
# time
# 0.000000  5.237591e-07 -1.322277e-10
# 0.000057  1.251310e-04 -2.204541e-08
# 0.007327  1.766684e-04 -1.784376e-08
# 0.011164  2.260040e-04  3.067193e-09
# 0.016747  2.784715e-04  2.583536e-08
#
# [5 rows x 26 columns]

# %%
n_rows = 5
df['response_final'].head(n_rows)
# Out:
#        bobble_bobble_balance_controller_bb_controller_status__ControlMode  \
# time
# 0.000                                                0.0
# 0.005                                                0.0
# 0.007                                                0.0
# 0.015                                                0.0
# 0.020                                                0.0
#
#        bobble_bobble_balance_controller_bb_controller_status__DesiredTilt  \
# time
# 0.000                                                0.0
# 0.005                                                0.0
# 0.007                                                0.0
# 0.015                                                0.0
# 0.020                                                0.0
#
#        bobble_bobble_balance_controller_bb_controller_status__DesiredTurnRate  \
# time
# 0.000                                                0.0
# 0.005                                                0.0
# 0.007                                                0.0
# 0.015                                                0.0
# 0.020                                                0.0
#
#        bobble_bobble_balance_controller_bb_controller_status__DesiredVelocity  \
# time
# 0.000                                                0.0
# 0.005                                                0.0
# 0.007                                                0.0
# 0.015                                                0.0
# 0.020                                                0.0
#
#        bobble_bobble_balance_controller_bb_controller_status__ForwardVelocity  \
# time
# 0.000                                       1.333773e-06
# 0.005                                       8.876815e-07
# 0.007                                       8.193197e-07
# 0.015                                       1.228979e-07
# 0.020                                       1.843469e-08
#
#        bobble_bobble_balance_controller_bb_controller_status__Heading  \
# time
# 0.000                                           0.001273
# 0.005                                           0.001306
# 0.007                                           0.000421
# 0.015                                          -0.004207
# 0.020                                          -0.005781
#
#        bobble_bobble_balance_controller_bb_controller_status__HeadingEffort  \
# time
# 0.000                                                0.0
# 0.005                                                0.0
# 0.007                                                0.0
# 0.015                                                0.0
# 0.020                                                0.0
#
#        bobble_bobble_balance_controller_bb_controller_status__LeftMotorEffortCmd  \
# time
# 0.000                                                0.0
# 0.005                                                0.0
# 0.007                                                0.0
# 0.015                                                0.0
# 0.020                                                0.0
#
#        bobble_bobble_balance_controller_bb_controller_status__LeftMotorPosition  \
# time
# 0.000                                       54493.652344
# 0.005                                       54493.652344
# 0.007                                       54493.652344
# 0.015                                       54493.652344
# 0.020                                       54493.652344
#
#        bobble_bobble_balance_controller_bb_controller_status__LeftMotorVelocity  \
# time
# 0.000                                           0.001554
# 0.005                                           0.000952
# 0.007                                           0.000950
# 0.015                                           0.000000
# 0.020                                           0.000000
#
#            ...       \
# time       ...
# 0.000      ...
# 0.005      ...
# 0.007      ...
# 0.015      ...
# 0.020      ...
#
#        bobble_bobble_balance_controller_bb_controller_status__TiltEffort  \
# time
# 0.000                                                0.0
# 0.005                                                0.0
# 0.007                                                0.0
# 0.015                                                0.0
# 0.020                                                0.0
#
#        bobble_bobble_balance_controller_bb_controller_status__TiltRate  \
# time
# 0.000                                          -0.567390
# 0.005                                           1.040550
# 0.007                                          -0.147448
# 0.015                                          -0.183944
# 0.020                                           0.173516
#
#        bobble_bobble_balance_controller_bb_controller_status__TurnRate   time  \
# time
# 0.000                                           0.337586                0.000
# 0.005                                           0.171461                0.005
# 0.007                                          -0.138001                0.007
# 0.015                                          -0.083195                0.015
# 0.020                                          -1.768036                0.020
#
#        DerivedHeading  DesiredHeading  DesiredXPos  DesiredYPos   DerivedXPos  \
# time
# 0.000        0.001273             0.0          0.0          0.0  5.553636e-09
# 0.005        0.001306             0.0          0.0          0.0  7.260637e-09
# 0.007        0.000421             0.0          0.0          0.0  1.102951e-08
# 0.015       -0.004207             0.0          0.0          0.0  1.138284e-08
# 0.020       -0.005781             0.0          0.0          0.0  1.143584e-08
#
#         DerivedYPos
# time
# 0.000  1.246498e-13
# 0.005  1.509092e-13
# 0.007  1.389132e-13
# 0.015  1.117045e-13
# 0.020  1.067777e-13
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Search for a column
# Here's how to search for a column(s) in a data frame.

# %%
search_string = 'Vel'
found_data = df['response_drive_square'].filter(regex=search_string)
found_data.head()
# Out:
#           bobble_bobble_balance_controller_bb_controller_status__DesiredVelocity  \
# time
# 0.000000                                                0.0
# 0.000057                                                0.0
# 0.007327                                                0.0
# 0.011164                                                0.0
# 0.016747                                                0.0
#
#           bobble_bobble_balance_controller_bb_controller_status__ForwardVelocity  \
# time
# 0.000000                                       8.370811e-13
# 0.000057                                       1.826727e-02
# 0.007327                                       1.601190e-02
# 0.011164                                       1.085557e-02
# 0.016747                                       6.816792e-03
#
#           bobble_bobble_balance_controller_bb_controller_status__LeftMotorVelocity  \
# time
# 0.000000                                       1.384645e-09
# 0.000057                                       5.582066e+01
# 0.007327                                       3.497360e+01
# 0.011164                                       2.093998e+01
# 0.016747                                       1.253754e+01
#
#           bobble_bobble_balance_controller_bb_controller_status__RightMotorVelocity
# time
# 0.000000                                       8.231131e-11
# 0.000057                                       4.928281e-11
# 0.007327                                       2.950743e-11
# 0.011164                                       1.766719e-11
# 0.016747                                       1.057800e-11

# %% [markdown]
# # Plot Trajectories

# %% [markdown]
# ### Velocity Plot

# %%
# %matplotlib inline
cfg = pc['velocity'].copy()
cfg['runs'] = ['tilt_response_kp_0.5_kd_0.075', 'tilt_response_kp_0.8_kd_0.075', 'tilt_response_kp_1.1_kd_0.075']
cfg['colors'] = ['orange', 'blue', 'red']
cfg['legend'] = {
    'Kp 0.5': {
        'color': 'orange',
        'linestyle': '-'
    },
    'Kp 0.8': {
        'color': 'blue',
        'linestyle': '-'
    },
    'Kp 1.1': {
        'color': 'red',
        'linestyle': '-'
    },
}
cfg['xlim'] = [0.0, 8.0]
make_static_plot(df, cfg, 'VelocityVsTime')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-af64f962949b> in <module>()
#      18 }
#      19 cfg['xlim'] = [0.0, 8.0]
# ---> 20 make_static_plot(df, cfg, 'VelocityVsTime')
#
# /home/mike/Work/SOE/BobbleBot/src/analysis_tools/src/analysis_tools/plots.pyc in make_static_plot(df, pc, plot_name, plot_func, savefig, dpi, height, width)
#      73     fig = plt.figure(figsize=(height, width), dpi=dpi)
#      74     ax1 = fig.add_subplot(111)
# ---> 75     plot_func(ax1, df, pc)
#      76     fig.tight_layout()
#      77     sns.despine()
#
# /home/mike/Work/SOE/BobbleBot/src/analysis_tools/src/analysis_tools/plots.pyc in coplot_var_for_runs(axis, data, pc)
#      40                                             linestyle=pc['linestyles'][index], label='_nolegend_')
#      41             else:
# ---> 42                 data[run][pc['y_var']].plot(ax=axis, color=pc['colors'][index], label='_nolegend_')
#      43     apply_common_plot_styles(axis, pc)
#      44
#
# KeyError: 'tilt_response_kp_0.5_kd_0.075'

# %% [markdown]
# ### Tilt Plot

# %%
# %matplotlib inline
cfg = pc['measured_tilt'].copy()
cfg['runs'] = ['tilt_response_kp_0.5_kd_0.075', 'tilt_response_kp_0.8_kd_0.075', 'tilt_response_kp_1.1_kd_0.075']
cfg['colors'] = ['orange', 'blue', 'red']
cfg['legend'] = {
    'Kp 0.5': {
        'color': 'orange',
        'linestyle': '-'
    },
    'Kp 0.8': {
        'color': 'blue',
        'linestyle': '-'
    },
    'Kp 1.1': {
        'color': 'red',
        'linestyle': '-'
    },
}
cfg['xlim'] = [0.0, 8.0]
make_static_plot(df, cfg, 'TiltVsTime')

# %% [markdown]
# ### Turn Rate Plot

# %%
# %matplotlib inline
cfg = pc['turn_rate'].copy()
cfg['runs'] = ['response_hw_testing']
cfg['xlim'] = [0.0, 60.0]
make_static_plot(df, cfg, 'TurnRateVsTime')

# %% [markdown]
# ### Heading Plot

# %%
# %matplotlib inline
cfg = pc['heading'].copy()
cfg['runs'] = ['response_hw_testing']
cfg['xlim'] = [0.0, 60.0]
make_static_plot(df, cfg, 'DerivedHeadingVsTime')

# %% [markdown]
# ### Position Plot

# %%
# %matplotlib inline
cfg = pc['position_derived'].copy()
cfg['runs'] = ['response_hw_testing', 'response_final']
cfg['xlim'] = [-0.25, 1.25]
cfg['ylim'] = [-0.25, 1.25]
cfg['title'] = 'HW vs Sim Square Drive - Position Response'
cfg['colors'] = ['red', 'blue']
cfg['legend'] = {
    'HW': {
        'color': 'red',
        'linestyle': '-'
    },
    'Sim': {
        'color': 'blue',
        'linestyle': '-'
    },
}
make_static_plot(df, cfg, 'SimVsHwPositionVsTime')

# %%
# %matplotlib inline
cfg = pc['position_control'].copy()
cfg['runs'] = ['response_final']
cfg['xlim'] = [-0.5, 1.5]
cfg['ylim'] = [-0.5, 1.5]
make_static_plot(df, cfg, 'PositionControl', plot_func=desired_vs_actual_for_runs)

# %%
# %matplotlib inline
cfg = pc['position_control'].copy()
cfg['runs'] = ['response_hw_testing']
cfg['xlim'] = [-1.5, 5.5]
cfg['ylim'] = [-1.5, 5.5]
make_static_plot(df, cfg, 'PositionControl', plot_func=desired_vs_actual_for_runs)

# %% [markdown]
# # Control Commands vs Response

# %% [markdown]
# ### Loop Jitter

# %%
#%matplotlib inline
#cfg = pc['loop_jitter'].copy()
#cfg['runs'] = ['response_drive_square']
#make_static_plot(df, cfg, 'LoopJitter')

# %% [markdown]
# ### Desired Velocity vs Actual

# %%
# %matplotlib inline
cfg = pc['velocity_control'].copy()
cfg['runs'] = ['response_hw_testing']
cfg['xlim'] = [0, 60]
make_static_plot(df, cfg, 'VelocityControl', plot_func=desired_vs_actual_for_runs)

# %%
# %matplotlib inline
cfg = pc['velocity_control'].copy()
cfg['runs'] = ['response_hw_testing']
cfg['xlim'] = [0, 60]
make_static_plot(df, cfg, 'VelocityControl', plot_func=desired_vs_actual_for_runs)

# %% [markdown]
# ### Desired Heading vs Actual

# %%
# %matplotlib inline
cfg = pc['heading_control'].copy()
cfg['runs'] = ['response_hw_testing']
cfg['xlim'] = [0, 60]
make_static_plot(df, cfg, 'HeadingControl', plot_func=desired_vs_actual_for_runs)

# %%
# %matplotlib inline
cfg = pc['heading_control'].copy()
cfg['runs'] = ['response_final']
cfg['xlim'] = [0, 60]
make_static_plot(df, cfg, 'HeadingControl', plot_func=desired_vs_actual_for_runs)

# %% [markdown]
# ## Desired Turn Rate vs Actual

# %%
# %matplotlib inline
cfg = pc['turning_control'].copy()
cfg['runs'] = ['response_hw_testing']
cfg['xlim'] = [0, 60]
make_static_plot(df, cfg, 'TurningControl', plot_func=desired_vs_actual_for_runs)

# %% [markdown]
# # Hardware vs Sim
